# %% [markdown]
# <h1>📝 Notes</h1>
# <p style="color: rgba($color: #FFFFFF, $alpha: 0.7);">Notes for server side logic. Deals with Auth and Database implentation. Uses expressjs for requests from the front end. </p>
#
# <h2>🖥️ Tech Stack</h2>
#
# <div style="color: #ffc710; font-size: 20px">Server: <span style="color: #ffffff">Expressjs + nodejs</span></div>
# <div style="color: #ffc710; font-size: 20px">Auth: <span style="color: #ffffff">Auth0</span></div>
# <div style="color: #ffc710; font-size: 20px">Database: <span style="color: #ffffff">MongoDB</span></div>
#
#
# <h2>🔐 Authentication Flow</h2>
#
# <span style="color: #ff006e; font-weight:600;">1.</span> React → Auth0 login
# <span style="color: #ff006e; font-weight:600;">2.</span> Auth0 → JWT
# <span style="color: #ff006e; font-weight:600;">3.</span> React stores token
# <span style="color: #ff006e; font-weight:600;">4.</span> API request with JWT
# <span style="color: #ff006e; font-weight:600;">5.</span> Express verifies token
# <span style="color: #ff006e; font-weight:600;">6.</span> Express queries MongoDB
# <span style="color: #ff006e; font-weight:600;">7.</span> Response returned
